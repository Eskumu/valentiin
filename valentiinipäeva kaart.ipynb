# %%
import matplotlib.pyplot as plt
import numpy as np

title = "Ma armastan sind Annika!"
sub_title = "Ilusat valentiinipäeva!"
color = "red"
color_accent = "black"
zoom = 3


t = np.arange(-3, 3, 0.001)
x = zoom * (16 * np.sin(t) ** 3)
y = zoom * (13 * np.cos(t) - 5 * np.cos(2 * t) - 2 * np.cos(3 * t)  - np.cos(4 * t))

with plt.xkcd():
    fig = plt.figure()
    ax = fig.add_axes((0.1, 0.2, 0.8, 0.7))
    ax.fill_between(x, y, facecolor=color, interpolate=True)
    ax.plot(x, y, color=color_accent, linewidth=4)

    plt.xticks([])
    plt.yticks([])
    
    plt.annotate(title,xy=(0, 0), xytext=(-35, 0), size=20)
    plt.annotate(sub_title,xy=(0, 0), xytext=(-20, -10))
    
    fig.text(
    0.8, 0.1,
    '- Kristjan',
    ha='center')
    
    plt
